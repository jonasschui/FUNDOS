# %%
# load in dependent libraries
import pandas as pd
from nltk.tokenize import word_tokenize
import nltk.classify
from collections import defaultdict
import re
from nltk import *
import collections, itertools
from nltk.metrics import precision, recall
from nltk.corpus import stopwords 
from nltk.stem import PorterStemmer 
#from featx import bag_of_words, high_information_words

# %%
# load in the training data
train_df = pd.read_csv("data/HCR/train/orig/HCR_formatted_train.csv")
# retrieve the possible labels from the training data
categories = list(set(train_df['sentiment']))
categories
# Out:
# ['positive', 'negative', 'neutral']

# %%
# mannaully coppied the featx bag_of_words and high_information_words module since featx package is not available for conda
def high_information_words(labelled_words, score_fn=BigramAssocMeasures.chi_sq, min_score=5):
    word_fd = FreqDist()
    label_word_fd = ConditionalFreqDist()

    for label, words in labelled_words:
        for word in words:
            word_fd[word] += 1
            label_word_fd[label][word] += 1

    n_xx = label_word_fd.N()
    high_info_words = set()

    for label in label_word_fd.conditions():
        n_xi = label_word_fd[label].N()
        word_scores = collections.defaultdict(int)

        for word, n_ii in label_word_fd[label].items():
            n_ix = word_fd[word]
            score = score_fn(n_ii, (n_ix, n_xi), n_xx)
            word_scores[word] = score

        bestwords = [word for word, score in word_scores.items() if score >= min_score]
        high_info_words |= set(bestwords)

    return high_info_words



def bag_of_words(words):
    return dict([(word, True) for word in words])

# %% [markdown]
# REMINDER! : CONSIDER REMOVING STOPWORDS, STEMMING

# %%
def tokenize(tweet):
    tokens = word_tokenize(tweet)
    tokens = [token.lower() for token in tokens]
    # remove items that are not alphabetics
    for token in tokens:
        if token.isalpha() == False:
            tokens.remove(token)
    # remove punctuation and other tokens
    for token in tokens:
        if token in '!;@#$%^&*().,\/?~1234567890':
            tokens.remove(token)
    
    # remove urls
    regex = re.compile(r'^[/]+')
    for token in tokens:
        if regex.match(token):
            tokens.remove(token)
    '''
    # remove stopwords
    stop_words = set(stopwords.words('english')) 
    for token in tokens: 
        if token in stop_words: 
            tokens.remove(token) 
            
    # word stemmer
    stemmed_tokens = []
    ps = PorterStemmer() 
    for token in tokens:
        stemmed = ps.stem(token)
        stemmed_tokens.append(stemmed)
    '''
    
    bag = bag_of_words(tokens)
    return bag

# %%
# create list of training features
train_feats = list ()
for i, row in train_df.iterrows():
    if row[2] in categories:
        bag_cat = row[2]
    tweet_text = row[1]
    # tokenize tweets and put tokens in bag of words
    bag = tokenize(tweet_text)
    train_feats.append((bag, bag_cat))

# %%
# obtain the high information words
def high_information(train_feats, categories):
    labelled_words = [(category, []) for category in categories]

    # convert the formatting of our features to that required by high_information_words
    words = defaultdict(list)
    all_words = list()
    for category in categories:
        words[category] = list()

    for feat in train_feats:
        category = feat[1]
        bag = feat[0]
        for w in bag.keys():
            words[category].append(w)
            all_words.append(w)
            #break

    labelled_words = [(category, words[category]) for category in categories]
    
    # calculate high information words
    # note: to adjust min occurence score add min_score = n
    high_info_words = set(high_information_words(labelled_words,min_score = 2))
    #print(high_info_words)
    #high_info_words contains a list of high-information words. You may want to use only these for classification.
    # You can restrict the words in a bag of words to be in a given 2nd list (e.g. in function read_files)
    #bag_of_words_in_set(words, high_info_words)
    
    print("  Number of words in the data: %i" % len(all_words))
    print("  Number of distinct words in the data: %i" % len(set(all_words)))
    print("  Number of distinct 'high-information' words in the data: %i" % len(high_info_words))

    return high_info_words

# %%
high_info_words = high_information(train_feats, categories)
new_feats = []
for tup in train_feats:
    dic, sentiment = tup
    new_dict = dict((k,v) for k,v in dic.items() if k in high_info_words)
    new_feats.append(tuple((new_dict, sentiment)))
    
train_feats = new_feats
# Out:
#   Number of words in the data: 13431
#   Number of distinct words in the data: 3113
#   Number of distinct 'high-information' words in the data: 1393

# %%
# trains a classifier
def train(train_feats):
    classifier = nltk.classify.NaiveBayesClassifier.train(train_feats)
    return classifier
    # the following code uses the classifier with add-1 smoothing (Laplace)
    # You may choose to use that instead
    #from nltk.probability import LaplaceProbDist
    #classifier = nltk.classify.NaiveBayesClassifier.train(train_feats, estimator=LaplaceProbDist)

# %%
train_feats[0]
# Out:
# ({'rt': True,
#   'it': True,
#   'usa': True,
#   'and': True,
#   'give': True,
#   'for': True,
#   'gop': True,
#   'tcot': True},
#  'negative')

# %%
classifier = train(train_feats)

# %%
classifier

# %%
# create list of development features
tweet = 'to play whack-a-mole with her giant gavel #hcr' 
# tokenize tweets and put tokens in bag of words
bag = tokenize(tweet)
print(classifier.classify(bag))
# Out:
# positive

# %%
# load in the development data
dev_df = pd.read_csv("data/HCR/dev/orig/HCR_formatted_dev.csv")
# retrieve the possible labels from the training data

# %%
tweet = dev_df.loc[3,'content']
classifier.classify(tokenize(tweet))
# Out:
# 'positive'

# %%
#type(classifier.classify(
#    tokenize(
#        dev_df.content)))
#dev_df['predicted'] = classifier.classify(tokenize(dev_df['content']))
#dev_df.head()
predictions = []
for i, row in dev_df.iterrows():
    tweet = row[2]
    prediction = classifier.classify(tokenize(tweet))
    predictions.append(prediction)
                                     
dev_df['predicted'] = predictions
dev_df
# Out:
#      Unnamed: 0     tweet id  \
# 0             0  10830146586
# 1             1  10829805730
# 2             2  10830200492
# 3             3  10829105860
# 4             4  10830281768
# 5             5  10829610415
# 6             6  10830265628
# 7             7  10827492775
# 8             8  10830232206
# 9             9  10830089102
# 10           10  10830366879
# 11           11  10830445967
# 12           12  10830419024
# 13           13  10830224555
# 14           14  10830509833
# 15           15  10830548147
# 16           16  10830501515
# 17           17  10828169696
# 18           18  10830519040
# 19           19  10830623081
# 20           20  10829671367
# 21           21  10830731011
# 22           22  10830634629
# 23           23  10830762506
# 24           24  10828999989
# 25           25  10830772477
# 26           26  10799514265
# 27           27  10830839860
# 28           28  10830942027
# 29           29  10830952895
# ..          ...          ...
# 636         792  10850054391
# 637         793  10849137681
# 638         795  10849722161
# 639         796  10850031693
# 640         797  10850047448
# 641         798  10850105957
# 642         799  10850125431
# 643         800  10850096509
# 644         801  10849664103
# 645         802  10850109267
# 646         803  10849907908
# 647         805  10849290220
# 648         815  10850223798
# 649         816  10850260061
# 650         817  10849155050
# 651         818  10849799182
# 652         819  10850239878
# 653         820  10850315198
# 654         821  10850351854
# 655         822  10848455149
# 656         824  10850349085
# 657         825  10850145453
# 658         826  10850358513
# 659         828  10850366479
# 660         829  10848803254
# 661         831  10850367636
# 662         834  10850232850
# 663         835  10850407476
# 664         837  10850410950
# 665         838  10850241290
#
#                                                content sentiment predicted
# 0    Despite reports, Pelosi aides say Rep. Stupak ...   neutral  positive
# 1    Looks like Pelosi is getting ready to play wha...  negative  negative
# 2    It is great to know that there are people who ...  positive  negative
# 3    3/21 the anniversary of my mother's death. Ins...  positive  positive
# 4    Black leaders supporting #hcr bill are more ak...  negative  negative
# 5    Contact @LorettaSanchez CoS & urge YES on #HCR...  positive  positive
# 6    These guys are straight up parroting Glenn Bec...  negative  negative
# 7    RT @Gabe_Holmstrom: If R's were as concerned a...  negative  negative
# 8    RT @MediaLizzy: STUPAK office recording yeas &...   neutral  negative
# 9    STUPAK office recording yeas & nays of callers...   neutral  negative
# 10   RT @NRCC: Brian #Baird's (D, #WA03) `YES' vote...  negative  positive
# 11   Okay, this is a done deal. Anybody knows a goo...  positive  positive
# 12   SAVE A PRESIDENCY - KILL A CONSTITUTION?? http...  negative  negative
# 13   LMAO! moments before #HCR passes and there are...  positive  positive
# 14   Speaker Pelosi wielding the same gavel today u...  positive  positive
# 15   RT @blackjedi47    Since #GOP hates to take re...  negative  negative
# 16   Today #HCR will pass in DC Also #immigration m...   neutral   neutral
# 17   Today's TeaParty recruitment special - free ho...  negative  negative
# 18   Watch #hcr vote live. http://www.huffingtonpos...   neutral   neutral
# 19   RT @philipaklein: RT @JeffreyYoung_HC: Dem Rep...   neutral   neutral
# 20   RT @LarryGeary: We need to find EXCELLENT, CON...  positive  negative
# 21   RT @toddeherman: RT @GOPinkPolitics: DON'T GIV...  negative  negative
# 22   Why was the vote held 25 minutes?'' So we coul...  negative  negative
# 23   To those in US who r working so hard to deny 3...  positive  positive
# 24   Watching, probably the best show on TV today, ...   neutral  negative
# 25   This Executive Order crap is a farce. It's not...  negative  negative
# 26   Larrey Anderson: Probable Constitutional Chall...  negative  negative
# 27   The American Republic will endure until the da...  negative  negative
# 28   Stupak's office is counting calls...just say N...  negative  negative
# 29   IRS DIRECT WITHDRAWAL FROM YOU BANK ACCT? @nei...  negative  negative
# ..                                                 ...       ...       ...
# 636  Boehner Alert Level raised to Burnt Sienna. #h...  negative  negative
# 637  The bill ''hurts our seniors and special needs...  negative   neutral
# 638  when I asked DeLauro what provision of Constit...  negative  negative
# 639  Boehner: ''I rise tonite with a sad and heavy ...  negative  negative
# 640  C-SPAN: Here we go, it's Boehner time! At leas...  negative  negative
# 641  Rep John Boehner - PROOF THE GOP LOVES PEOPLE ...  negative  negative
# 642  RT @LynCKos: Here we go! Boehner: ''Oompah Loo...  negative  positive
# 643  um...boehner? people hate congress because of ...  negative  negative
# 644  RT @jgoffutt: If #hcr passes CIA will join Sat...  positive   neutral
# 645  Whatever Rep. Boehner, @BarackObama tried bipa...  negative  negative
# 646  Free preventative care for all, even for repub...  negative  negative
# 647  Republicans on the House floor keep saying the...  positive  negative
# 648  Announce your vote one by one, you coward Demo...  negative  negative
# 649  Making sure I have the argument straight: #hcr...  negative  positive
# 650  2K people show up to protest #HCR in DC today ...   neutral   neutral
# 651  WHO IS THIS ROCKSTAR LEGISLATOR, AND WHERE ARE...  positive  negative
# 652  YES: Boehner calls for announcing votes one at...  positive  negative
# 653  Obey is in the chair for a reason. He knows Ho...   neutral  negative
# 654                         Shut up John Boehner. #hcr  negative   neutral
# 655  RT @Jeremycrow4life\n  \n17,000 new IRS agents...  negative  negative
# 656  RT @nerdette: John Boehner does a real disserv...  negative  negative
# 657  in john boehner the gop has the leader they de...  negative  negative
# 658  yes boehner what i see frightens me and it is ...  negative  negative
# 659  RT @DavidCornDC: Boehner is truly grandstandin...  negative   neutral
# 660  RT @GOPLeader: FACT CHECK: Gov't Takeover of H...  negative  negative
# 661  RT @markos RT @nerdette: John Boehner does a r...  negative  negative
# 662  rt @alpha1906 Boehner: The man who passed out ...  negative  negative
# 663  The MINORITY leader is saying the MAJORITY is ...  negative   neutral
# 664  rt @kathrynlopez boehner had 2 get mad, it's t...  negative  negative
# 665  every time boehner crys an angel gets it wings...  positive   neutral
#
# [666 rows x 5 columns]

# %%
true_positive = 0
#true_negative = 0
false_positive = 0
#false_negative = 0


for i, row in dev_df.iterrows():
    sent = row[3]
    pred = row[4]
    if sent == pred:
        true_positive += 1
    elif sent != pred:
        false_positive += 1
print("TRUE",true_positive)
print("FALSE",false_positive)
# Out:
# TRUE 366
# FALSE 300

# %%
import numpy as np
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score

precision_recall_fscore_support(dev_df.sentiment, dev_df.predicted, labels = ['negative','neutral','positive'])#(, average='micro')
accuracy_score(dev_df.sentiment, dev_df.predicted)
# Out:
# 0.5495495495495496

# %%
# load in the development data
dev_df = pd.read_csv("data/HCR/dev/orig/HCR_formatted_dev.csv")
# retrieve the possible labels from the training data
categories = list(set(dev_df['sentiment']))
categories
# Out:
# ['neutral', 'positive', 'negative']

# %%
# create list of development features
dev_feats = list ()
for i, row in dev_df.iterrows():
    if row[3] in categories:
        bag_cat = row[3]
    tweet_text = row[2]
    # tokenize tweets and put tokens in bag of words
    bag = tokenize(tweet_text)
    dev_feats.append((bag, bag_cat))
bag
# Out:
# {'every': True,
#  'time': True,
#  'boehner': True,
#  'crys': True,
#  'an': True,
#  'angel': True,
#  'gets': True,
#  'it': True,
#  'wings': True,
#  'hcr': True}

# %%
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\12859087\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
def evaluation(classifier, test_feats, categories):
    print ("\n##### Evaluation...")
    print("  Accuracy: %f" % nltk.classify.accuracy(classifier, test_feats))
    precisions, recalls = precision_recall(classifier, test_feats)
    print(precisions, recalls)
    f_measures = calculate_f(precisions, recalls)  

    print(" |-----------|-----------|-----------|-----------------|")
    print(" |%-11s|%-11s|%-11s|%-11s|" % ("category","precision","recall","F-measure"))
    print(" |-----------|-----------|-----------|-----------------|")
    for category in categories:
        if precisions[category] is None:
            print(" |%-11s|%-11s|%-11s|%-11s|" % (category, "NA", "NA", "NA"))
        else:
            print(" |%-11s|%-11f|%-11f|%-11s|" % (category, precisions[category], recalls[category], f_measures[category]))
    print(" |-----------|-----------|-----------|------------------|")

# %%
from classification import precision_recall

# %%
def calculate_f(precisions, recalls):
    f_measures = {}
    #TODO calculate the f measure for each category using as input the precisions and recalls
    for precision, recall in zip(precisions.items(), recalls.items()):
        f_measures[precision[0]] = ((2*precision[1])*recall[1])/ (precision[1] + recall[1])
    return f_measures

# %%
def precision_recall(classifier, testfeats):
    refsets = collections.defaultdict(set)
    testsets = collections.defaultdict(set)
    
    for i, (feats, label) in enumerate(testfeats):
        refsets[label].add(i)
        observed = classifier.classify(feats)
        testsets[observed].add(i)
    
    precisions = {}
    recalls = {}
    
    for label in classifier.labels():
        precisions[label] = precision(refsets[label], testsets[label])
        recalls[label] = recall(refsets[label], testsets[label])
    
    return precisions, recalls

# %%
evaluation(classifier, dev_feats, categories)
# Out:
# ##### Evaluation...
#   Accuracy: 1.000000
# {'negative': 1.0, 'neutral': None, 'positive': None} {'negative': 1.0, 'neutral': None, 'positive': None}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-893cb3f04517> in <module>()
# ----> 1 evaluation(classifier, dev_feats, categories)
#
# <ipython-input-22-702821e77ba2> in evaluation(classifier, test_feats, categories)
#       4     precisions, recalls = precision_recall(classifier, test_feats)
#       5     print(precisions, recalls)
# ----> 6     f_measures = calculate_f(precisions, recalls)
#       7
#       8     print(" |-----------|-----------|-----------|-----------------|")
#
# <ipython-input-24-0ec94aadf7d1> in calculate_f(precisions, recalls)
#       3     #TODO calculate the f measure for each category using as input the precisions and recalls
#       4     for precision, recall in zip(precisions.items(), recalls.items()):
# ----> 5         f_measures[precision[0]] = ((2*precision[1])*recall[1])/ (precision[1] + recall[1])
#       6     return f_measures
#
# TypeError: unsupported operand type(s) for *: 'int' and 'NoneType'
