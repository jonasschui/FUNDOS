# %%
# load in dependent libraries
import pandas as pd
from nltk.tokenize import word_tokenize
import nltk.classify
from collections import defaultdict
import re
from nltk import *
import collections, itertools
from nltk.metrics import precision, recall
from nltk.corpus import stopwords 
from nltk.stem import PorterStemmer 
#from featx import bag_of_words, high_information_words

# %%
# load in the training data
train_df = pd.read_csv("hcr_omd.csv")
# retrieve the possible labels from the training data
categories = list(set(train_df['sentiment']))
categories
# Out:
# ['negative', 'positive', 'neutral']

# %%
train_df
# Out:
#       Unnamed: 0                                              tweet sentiment
# 0              0  Despite reports, Pelosi aides say Rep. Stupak ...   neutral
# 1              1  Looks like Pelosi is getting ready to play wha...  negative
# 2              2  It is great to know that there are people who ...  positive
# 3              3  3/21 the anniversary of my mother's death. Ins...  positive
# 4              4  Black leaders supporting #hcr bill are more ak...  negative
# 5              5  Contact @LorettaSanchez CoS & urge YES on #HCR...  positive
# 6              6  These guys are straight up parroting Glenn Bec...  negative
# 7              7  RT @Gabe_Holmstrom: If R's were as concerned a...  negative
# 8              8  RT @MediaLizzy: STUPAK office recording yeas &...   neutral
# 9              9  STUPAK office recording yeas & nays of callers...   neutral
# 10            10  RT @NRCC: Brian #Baird's (D, #WA03) `YES' vote...  negative
# 11            11  Okay, this is a done deal. Anybody knows a goo...  positive
# 12            12  SAVE A PRESIDENCY - KILL A CONSTITUTION?? http...  negative
# 13            13  LMAO! moments before #HCR passes and there are...  positive
# 14            14  Speaker Pelosi wielding the same gavel today u...  positive
# 15            15  RT @blackjedi47    Since #GOP hates to take re...  negative
# 16            16  Today #HCR will pass in DC Also #immigration m...   neutral
# 17            17  Today's TeaParty recruitment special - free ho...  negative
# 18            18  Watch #hcr vote live. http://www.huffingtonpos...   neutral
# 19            19  RT @philipaklein: RT @JeffreyYoung_HC: Dem Rep...   neutral
# 20            20  RT @LarryGeary: We need to find EXCELLENT, CON...  positive
# 21            21  RT @toddeherman: RT @GOPinkPolitics: DON'T GIV...  negative
# 22            22  Why was the vote held 25 minutes?'' So we coul...  negative
# 23            23  To those in US who r working so hard to deny 3...  positive
# 24            24  Watching, probably the best show on TV today, ...   neutral
# 25            25  This Executive Order crap is a farce. It's not...  negative
# 26            26  Larrey Anderson: Probable Constitutional Chall...  negative
# 27            27  The American Republic will endure until the da...  negative
# 28            28  Stupak's office is counting calls...just say N...  negative
# 29            29  IRS DIRECT WITHDRAWAL FROM YOU BANK ACCT? @nei...  negative
# ...          ...                                                ...       ...
# 4671        3208  I vote Christiane Amanpour for VP! She could b...  negative
# 4672        3209  @TaiwanBrown yeah I saw it barack didnt k.o hi...  negative
# 4673        3210  they both blinked several times every time the...  negative
# 4674        3211  "palin turned down spin patrol in favor of rud...  negative
# 4675        3212  debate was a draw. Although I think Mccain cam...  positive
# 4676        3213  @mkantonelli I love writing ;/ but after work ...  positive
# 4677        3214  "#current #debate08  apparently the GOP is mak...  negative
# 4678        3215  @Imarilove i think they had to dose him with w...  negative
# 4679        3216  People called into CNN to ask why they intervi...  positive
# 4680        3217  RUUUUUUUUUUUUUUUUUUUUUUUUDY!!!!!!!!! #debate08...  positive
# 4681        3218  #debate08 I'm looking forward to the factcheck...  positive
# 4682        3219  "@Autumm too bad for ol' kissy, CNN was alread...  negative
# 4683        3220  @dksnyder you missed the bit where McCain talk...  negative
# 4684        3221  "@etherkiller Good point. Part of the post-deb...  negative
# 4685        3222  @VizionQuest RT: Obama: McCain you're right. M...  negative
# 4686        3223  ": #debate08 Truth is, I wanted Obama to do be...  negative
# 4687        3224  "#current #debate McCain has been totally agai...  negative
# 4688        3225  @newshour has hashtagged the debate  #debate08...   neutral
# 4689        3226  "#debate08  If McCain is Grandpa Simpson, then...  negative
# 4690        3227  #debate08 - Biden's good - mccain needs to sta...  negative
# 4691        3228  @shayera No kidding! I want to see her be inte...  negative
# 4692        3229  #debate08 FOX says McCain won the debate. MSNB...  negative
# 4693        3230  "#debate08 did your favorite candidate ""beat"...  negative
# 4694        3231  Future debate advice for Obama: 1) Fewer words...  negative
# 4695        3232                  @michaelszeto I disagree totally.  negative
# 4696        3233  "#momocrats #current seriously, as a woman, yo...  negative
# 4697        3234  http://www.drudgereport.com/ go vote..70-30 mc...  positive
# 4698        3235  "hosting a letter-writing campaign is easy, fu...  negative
# 4699        3236  #coat4d: Just because I was there doesn't make...  negative
# 4700        3237  #debate08 rt @blogdiva NPR is saying their aud...  negative
#
# [4701 rows x 3 columns]

# %%
#train_df = train_df.drop(['Unnamed: 0.1'],1)
#train_df = train_df.reindex(columns=['Unnamed: 0','tweet','sentiment'])
#train_df

# %%
# mannaully coppied the featx bag_of_words and high_information_words module since featx package is not available for conda
def high_information_words(labelled_words, score_fn=BigramAssocMeasures.chi_sq, min_score=5):
    word_fd = FreqDist()
    label_word_fd = ConditionalFreqDist()

    for label, words in labelled_words:
        for word in words:
            word_fd[word] += 1
            label_word_fd[label][word] += 1

    n_xx = label_word_fd.N()
    high_info_words = set()

    for label in label_word_fd.conditions():
        n_xi = label_word_fd[label].N()
        word_scores = collections.defaultdict(int)

        for word, n_ii in label_word_fd[label].items():
            n_ix = word_fd[word]
            score = score_fn(n_ii, (n_ix, n_xi), n_xx)
            word_scores[word] = score

        bestwords = [word for word, score in word_scores.items() if score >= min_score]
        high_info_words |= set(bestwords)

    return high_info_words



def bag_of_words(words):
    return dict([(word, True) for word in words])

# %% [markdown]
# REMINDER! : CONSIDER REMOVING STOPWORDS, STEMMING

# %%
def tokenize(tweet):
    tokens = word_tokenize(tweet)
    tokens = [token.lower() for token in tokens]
    # remove items that are not alphabetics
    for token in tokens:
        if token.isalpha() == False:
            tokens.remove(token)
    # remove punctuation and other tokens
    for token in tokens:
        if token in '!;@#$%^&*().,\/?~1234567890':
            tokens.remove(token)
    
    # remove urls
    regex = re.compile(r'^[/]+')
    for token in tokens:
        if regex.match(token):
            tokens.remove(token)
    
    
    # remove stopwords
    stop_words = set(stopwords.words('english')) 
    for token in tokens: 
        if token in stop_words: 
            tokens.remove(token) 
          
    # word stemmer
    stemmed_tokens = []
    ps = PorterStemmer() 
    for token in tokens:
        stemmed = ps.stem(token)
        stemmed_tokens.append(stemmed)
        
    # Snowbal-stemmer (WORKS BETTER)    
    from nltk.stem.snowball import SnowballStemmer
    stemmed_toks = []
    stemmer = SnowballStemmer("english")
    for token in tokens:
        stemmed = stemmer.stem(token)
        stemmed_toks.append(stemmed)
    
    bag = bag_of_words(stemmed_toks)
    return bag

# %%
train_df.head()
# Out:
#    Unnamed: 0                                              tweet sentiment
# 0           0  Despite reports, Pelosi aides say Rep. Stupak ...   neutral
# 1           1  Looks like Pelosi is getting ready to play wha...  negative
# 2           2  It is great to know that there are people who ...  positive
# 3           3  3/21 the anniversary of my mother's death. Ins...  positive
# 4           4  Black leaders supporting #hcr bill are more ak...  negative

# %%
# create list of training features
train_feats = list ()
counter = 0
for i, row in train_df.iterrows():
    if row[2] in categories:    
        bag_cat = row[2]
    tweet_text = row[1]
    counter += 1
    # tokenize tweets and put tokens in bag of words
    bag = tokenize(tweet_text)
    train_feats.append((bag, bag_cat))
    if counter % 100000 == 0:
        print(counter)

# %%
# obtain the high information words
def high_information(train_feats, categories):
    labelled_words = [(category, []) for category in categories]

    # convert the formatting of our features to that required by high_information_words
    words = defaultdict(list)
    all_words = list()
    for category in categories:
        words[category] = list()

    for feat in train_feats:
        category = feat[1]
        bag = feat[0]
        for w in bag.keys():
            words[category].append(w)
            all_words.append(w)
            #break

    labelled_words = [(category, words[category]) for category in categories]
    
    # calculate high information words
    # note: to adjust min occurence score add min_score = n
    high_info_words = set(high_information_words(labelled_words,min_score = 2))
    #print(high_info_words)
    #high_info_words contains a list of high-information words. You may want to use only these for classification.
    # You can restrict the words in a bag of words to be in a given 2nd list (e.g. in function read_files)
    # e.g. bag_of_words_in_set(words, high_info_words)
    
    print("  Number of words in the data: %i" % len(all_words))
    print("  Number of distinct words in the data: %i" % len(set(all_words)))
    print("  Number of distinct 'high-information' words in the data: %i" % len(high_info_words))

    return high_info_words

# %%
high_info_words = high_information(train_feats, categories)
# Out:
#   Number of words in the data: 50286
#   Number of distinct words in the data: 6612
#   Number of distinct 'high-information' words in the data: 2839

# %%
high_info_words = high_information(train_feats, categories)
new_feats = []
for tup in train_feats:
    dic, sentiment = tup
    new_dict = dict((k,v) for k,v in dic.items() if k in high_info_words)
    new_feats.append(tuple((new_dict, sentiment)))

train_feats = new_feats
# Out:
#   Number of words in the data: 50286
#   Number of distinct words in the data: 6612
#   Number of distinct 'high-information' words in the data: 2839

# %%
# trains a classifier
def train(train_feats):
    classifier = nltk.classify.NaiveBayesClassifier.train(train_feats)
    return classifier
    # the following code uses the classifier with add-1 smoothing (Laplace)
    # You may choose to use that instead
    #from nltk.probability import LaplaceProbDist
    #classifier = nltk.classify.NaiveBayesClassifier.train(train_feats, estimator=LaplaceProbDist)

# %%
train_feats[0]
# Out:
# ({'despit': True,
#   'aid': True,
#   'say': True,
#   'stupak': True,
#   'not': True,
#   'yes': True,
#   'vote': True,
#   'yet': True,
#   'hcr': True},
#  'neutral')

# %%
classifier = train(train_feats)

# %%
classifier

# %%
# create list of development features
tweet = 'have a bad nice good day' 
# tokenize tweets and put tokens in bag of words
bag = tokenize(tweet)
print(classifier.classify(bag))
# Out:
# negative

# %%
# load in the development data
dev_df = pd.read_csv("hcr_test_data.csv")
# retrieve the possible labels from the training data
dev_df.head()
# Out:
#    Unnamed: 0     tweet id                                            content  \
# 0           0  10729879540  50% of FoxNews.com readers think #hcr won't pa...
# 1           1  10740632762  NEW #teaparty sign download ---- Taking back o...
# 2           2  10780349787  RT @Marnus3: Note to Teabaggers: We took back ...
# 3           3  10781009520  RT @hippieprof: RT @loudhearted: RT @quaigee: ...
# 4           4  10727641557  I'm confident those that support #hcr will be ...
#
#   sentiment
# 0  negative
# 1  positive
# 2  positive
# 3  negative
# 4  negative

# %%
tweet = dev_df.loc[3,'content']
classifier.classify(tokenize(tweet))
# Out:
# 'negative'

# %%
#type(classifier.classify(
#    tokenize(
#        dev_df.content)))
#dev_df['predicted'] = classifier.classify(tokenize(dev_df['content']))
#dev_df.head()
predictions = []
for i, row in dev_df.iterrows():
    tweet = row[2]
    prediction = classifier.classify(tokenize(tweet))
    predictions.append(prediction)
                                     
dev_df['predicted'] = predictions
dev_df
# Out:
#      Unnamed: 0     tweet id  \
# 0             0  10729879540
# 1             1  10740632762
# 2             2  10780349787
# 3             3  10781009520
# 4             4  10727641557
# 5             5  10781735057
# 6             6  10723752009
# 7             7  10726487327
# 8             8  10739614533
# 9             9  10739944453
# 10           10  10740787497
# 11           11  10741769142
# 12           12  10742216567
# 13           13  10743491018
# 14           14  10746031643
# 15           15  10747976665
# 16           16  10778531386
# 17           17  10778706416
# 18           19  10781085744
# 19           21  10778725328
# 20           22  10743731523
# 21           23  10668465456
# 22           24  10752073191
# 23           25  10740962281
# 24           26  10776800977
# 25           27  10783430506
# 26           28  10784076137
# 27           29  10788344161
# 28           30  10789361580
# 29           31  10800881091
# ..          ...          ...
# 768         805  10728741474
# 769         806  10752963326
# 770         807  10757055732
# 771         808  10757979045
# 772         809  10670487729
# 773         810  10745548052
# 774         811  10728957865
# 775         812  10715742611
# 776         814  10697684831
# 777         815  10735059275
# 778         816  10733933276
# 779         817  10736638583
# 780         818  10736818753
# 781         819  10737072303
# 782         820  10737311140
# 783         821  10737638388
# 784         823  10737936564
# 785         824  10729482760
# 786         825  10737917622
# 787         826  10738086078
# 788         827  10734168054
# 789         828  10738555506
# 790         829  10735291561
# 791         830  10738719556
# 792         831  10737828505
# 793         833  10739010127
# 794         834  10738934557
# 795         835  10737735441
# 796         837  10739790175
# 797         838  10639441066
#
#                                                content sentiment predicted
# 0    50% of FoxNews.com readers think #hcr won't pa...  negative  negative
# 1    NEW #teaparty sign download ---- Taking back o...  positive  negative
# 2    RT @Marnus3: Note to Teabaggers: We took back ...  positive  negative
# 3    RT @hippieprof: RT @loudhearted: RT @quaigee: ...  negative  negative
# 4    I'm confident those that support #hcr will be ...  negative  positive
# 5    RT @BrettR4763: RT @Marnus3: Rep. Weiner expos...  negative  negative
# 6    @margaretacker #hcr I will not be muzzled! I'm...  negative  negative
# 7    GO TO YOUR US REPS OFFICE ON SATURDAY AND SAY ...  negative  positive
# 8    Retweet this if you are against a government t...  negative  negative
# 9    RT @RepKevinBrady: Retweet this if you are aga...  negative  negative
# 10   Every dissenting Democrat on #hcr, MUST pay a ...  negative   neutral
# 11   Thank you Rep. Schakowsky (@JanSchakowsky) for...  positive  positive
# 12   RIP ''I'm Just a Bill,'' School House Rock Mar...  negative   neutral
# 13   Retweet if you are against Obama's Health Care...  negative  negative
# 14   http://bit.ly/c2ujJi  Stand Against Obamacare ...  negative   neutral
# 15   Sad that people want our grandchildren and gre...  negative  negative
# 16   Fox is wall-to-wall #hcr. MSNBC showing ''Boos...   neutral   neutral
# 17   Retweet if you wish you could be at the Code R...  negative  negative
# 18   #ImTheKindOfPerson who thinks health care is a...  positive  positive
# 19   RT @theGOPalliance: Retweet if you wish you co...  negative  negative
# 20   WATCH: POTUS' remarks on #HCR in Fairfax, VA t...   neutral   neutral
# 21   I think the moment that the #TeaParty started ...  negative  negative
# 22   Retweet this if you don't give a damn what the...  negative  negative
# 23   Way to go #Teaparty! Harassing disabled guy re...  negative   neutral
# 24   #Christian Conservatism: The doctrine that God...  negative  positive
# 25   If YOU were SILENT about Bush creating the BIG...  negative  negative
# 26   #michellemalkin #conservative STALKS children ...  negative  negative
# 27   Righties are in MELTDOWN as their sad little t...  negative  positive
# 28   RT @OTOOLEFAN: Teabaggers have so much ''outra...  negative  negative
# 29   Losers. RT @RayBeckerman: Tea Party protesters...  negative  negative
# ..                                                 ...       ...       ...
# 768  O cites plaque in WH w/ TR quote: ''Aggressive...  positive  negative
# 769  Yeah - Obama - if this #hcr bill passes, it WI...  negative  negative
# 770  PATHETIC!!! WH harrassing fed employees on the...  negative  positive
# 771  #Teabaggers wouldn't opt out of Medicare or SS...  negative  negative
# 772  RT @BrentBozell For once, the @WashingtonPost ...  negative  negative
# 773  Did GLENN BECK and SARAH PALIN forget to take ...  negative  negative
# 774  @reppaulryan PARTY of NO! Donna Brazile's late...  negative  negative
# 775  Now for the Slaughter: Noonan: http://www.awes...  negative  negative
# 776  RT @BluegrassPundit: Obamacare House Vote Whip...   neutral  negative
# 777  I Still Believe We Can Do What's Right'': full...   neutral  negative
# 778  We fight #hcr bill with logic, numbers, and fa...  negative  negative
# 779  If giving pvt insurers $500+ b in subsidies ma...  negative  negative
# 780  Call DeFazio and tell him to vote yes for #hcr...  positive  positive
# 781  RT @PG_in_DC: Dem memo about #hcr messaging po...   neutral   neutral
# 782  Help make history on #HCR: http://bit.ly/7113l...  positive  positive
# 783  My mother always taught me they can have their...  negative  negative
# 784  RT @CatoInstitute: Seven myths about health ca...  negative  positive
# 785  If #hcr is so bad, shouldn't Republicans be wi...  positive  negative
# 786  Cantor says GOP needs 38 Dem. ''no'' votes to ...   neutral  negative
# 787  MT @Mathurm: Congress getting 100,001 phone ca...  positive  negative
# 788  More #hcr drama: Democratic caucus will meet w...   neutral   neutral
# 789  RT @fleckman: The Total List and Contact to ki...  negative  negative
# 790  Call to Action: March 20, 2010 Rally Against O...  negative  negative
# 791  @dailykos Leader of the Blue Dogs just switche...  positive   neutral
# 792  RT @seanhackbarth: RT @TomCoburn: I'll force H...   neutral  negative
# 793  Looks like Alan Boyd doesn't want to lose his ...  positive  positive
# 794  RT @MPOTheHill: Rep. Allen Boyd (D-Fla.) will ...  positive   neutral
# 795  RT @RepMaryFallin Did u know PelosiCare includ...  negative  negative
# 796  Just posted: Operation Nullification! What we ...  negative  negative
# 797  #HCR #healthcare Swing Voter: Gabrielle Giffor...   neutral   neutral
#
# [798 rows x 5 columns]

# %%
true_positive = 0
#true_negative = 0
false_positive = 0
#false_negative = 0


for i, row in dev_df.iterrows():
    sent = row[3]
    pred = row[4]
    if sent == pred:
        true_positive += 1
    elif sent != pred:
        false_positive += 1
print("TRUE",true_positive)
print("FALSE",false_positive)
# Out:
# TRUE 521
# FALSE 277

# %%
import numpy as np
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score

precision_recall_fscore_support(dev_df.sentiment, dev_df.predicted, labels = ['negative','neutral','positive'])#(, average='micro')
accuracy_score(dev_df.sentiment, dev_df.predicted)
# Out:
# 0.6528822055137845

# %%
# load in the development data
dev_df = pd.read_csv("data/HCR/dev/orig/HCR_formatted_dev.csv")
# retrieve the possible labels from the training data
categories = list(set(dev_df['sentiment']))
categories
# Out:
# ['neutral', 'positive', 'negative']

# %%
# create list of development features
dev_feats = list ()
for i, row in dev_df.iterrows():
    if row[3] in categories:
        bag_cat = row[3]
    tweet_text = row[2]
    # tokenize tweets and put tokens in bag of words
    bag = tokenize(tweet_text)
    dev_feats.append((bag, bag_cat))
bag
# Out:
# {'every': True,
#  'time': True,
#  'boehner': True,
#  'crys': True,
#  'an': True,
#  'angel': True,
#  'gets': True,
#  'it': True,
#  'wings': True,
#  'hcr': True}

# %%
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\12859087\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
def evaluation(classifier, test_feats, categories):
    print ("\n##### Evaluation...")
    print("  Accuracy: %f" % nltk.classify.accuracy(classifier, test_feats))
    precisions, recalls = precision_recall(classifier, test_feats)
    print(precisions, recalls)
    f_measures = calculate_f(precisions, recalls)  

    print(" |-----------|-----------|-----------|-----------------|")
    print(" |%-11s|%-11s|%-11s|%-11s|" % ("category","precision","recall","F-measure"))
    print(" |-----------|-----------|-----------|-----------------|")
    for category in categories:
        if precisions[category] is None:
            print(" |%-11s|%-11s|%-11s|%-11s|" % (category, "NA", "NA", "NA"))
        else:
            print(" |%-11s|%-11f|%-11f|%-11s|" % (category, precisions[category], recalls[category], f_measures[category]))
    print(" |-----------|-----------|-----------|------------------|")

# %%
from classification import precision_recall

# %%
def calculate_f(precisions, recalls):
    f_measures = {}
    #TODO calculate the f measure for each category using as input the precisions and recalls
    for precision, recall in zip(precisions.items(), recalls.items()):
        f_measures[precision[0]] = ((2*precision[1])*recall[1])/ (precision[1] + recall[1])
    return f_measures

# %%
def precision_recall(classifier, testfeats):
    refsets = collections.defaultdict(set)
    testsets = collections.defaultdict(set)
    
    for i, (feats, label) in enumerate(testfeats):
        refsets[label].add(i)
        observed = classifier.classify(feats)
        testsets[observed].add(i)
    
    precisions = {}
    recalls = {}
    
    for label in classifier.labels():
        precisions[label] = precision(refsets[label], testsets[label])
        recalls[label] = recall(refsets[label], testsets[label])
    
    return precisions, recalls

# %%
evaluation(classifier, dev_feats, categories)
# Out:
# ##### Evaluation...
#   Accuracy: 1.000000
# {'negative': 1.0, 'neutral': None, 'positive': None} {'negative': 1.0, 'neutral': None, 'positive': None}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-893cb3f04517> in <module>()
# ----> 1 evaluation(classifier, dev_feats, categories)
#
# <ipython-input-22-702821e77ba2> in evaluation(classifier, test_feats, categories)
#       4     precisions, recalls = precision_recall(classifier, test_feats)
#       5     print(precisions, recalls)
# ----> 6     f_measures = calculate_f(precisions, recalls)
#       7
#       8     print(" |-----------|-----------|-----------|-----------------|")
#
# <ipython-input-24-0ec94aadf7d1> in calculate_f(precisions, recalls)
#       3     #TODO calculate the f measure for each category using as input the precisions and recalls
#       4     for precision, recall in zip(precisions.items(), recalls.items()):
# ----> 5         f_measures[precision[0]] = ((2*precision[1])*recall[1])/ (precision[1] + recall[1])
#       6     return f_measures
#
# TypeError: unsupported operand type(s) for *: 'int' and 'NoneType'
